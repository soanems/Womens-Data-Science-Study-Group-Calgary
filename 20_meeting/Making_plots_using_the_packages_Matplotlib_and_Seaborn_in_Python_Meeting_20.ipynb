# %% [markdown]
# # <font color='blue'>**Women's Data Science Study Group-Calgary**</font>
# ## Making plots using the packages Matplotlib and Seaborn in Python
# #### Meeting 20
# ----
# Soane Mota \\
# March 20, 2021
#
# ----

# %% [markdown]
# # Notebook's Goal
#
# The goal of this notebook is to present some examples of plots using Seaborn and Matplotlib

# %% [markdown]
# # Diamonds dataset from Seaborn
#
#
# Columns information:
# * price price in US dollars (\$326--$18,823)
# * carat weight of the diamond (0.2-5.01)
# * cut quality of the cut (Fair, Good, Very Good, Premium, Ideal)
# * color diamond colour, from J (worst) to D (best)
# * clarity a measurement of how clear the diamond is (I1 (worst), SI2, SI1, VS2, VS1, VVS2, VVS1, IF (best))
# * x length in mm (0-10.74)
# * y width in mm (0-58.9)
# * z depth in mm (0-31.8)
# * depth total depth percentage = z / mean(x, y) = 2 * z / (x + y) (43--79)
# * table width of top of diamond relative to widest point (43--95)

# %% [markdown]
# ## Install libraries

# %%
# Import seaborn
import seaborn as sns
# Import matplotlib 
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

#Some configuration settings
# %matplotlib inline
pd.set_option("display.max_columns", 100)

# %%
# Apply the default theme
sns.set_theme()

# Load an example dataset
diamonds = sns.load_dataset("diamonds")

# %%
diamonds
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
diamonds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  category
#  2   color    53940 non-null  category
#  3   clarity  53940 non-null  category
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: category(3), float64(6), int64(1)
# memory usage: 3.0 MB

# %%
diamonds.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %% [markdown]
# # Pie plot using matplotlib

# %%
diamonds['cut'].value_counts().plot.pie()
plt.gca().set_aspect('equal')

# %% [markdown]
# # Make the plot with pandas

# %%
# Prepare Data
df = diamonds.groupby('cut').size()

df.plot(kind='pie', subplots=True, figsize=(8, 8))
plt.title("Pie Chart of cut")
plt.ylabel("")
plt.show()

# %% [markdown]
# # Bar plot using seaborn

# %%
sns.countplot('cut', data=diamonds)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # Horizontal bar plot using seaborn

# %%
sns.countplot(y= 'cut', data= diamonds)
plt.show()

# %%
sns.countplot(y= 'color', data= diamonds)
plt.show()

# %%
sns.countplot(y= 'clarity', data= diamonds)
plt.show()

# %% [markdown]
# ## Change the colour palette

# %%
# https://seaborn.pydata.org/tutorial/color_palettes.html
sns.countplot(y= 'clarity', data= diamonds, palette='Spectral')

# %%
sns.countplot(y= 'clarity', data= diamonds, palette='rocket')

# %% [markdown]
# # Save a palette to a variable:

# %%
palette = sns.color_palette("rocket")
 
# Use palplot and pass in the variable:
sns.palplot(palette)

# %% [markdown]
# # Examine distribution of price using seaborn

# %%
sns.displot(diamonds['price'])

# %% [markdown]
# # Examine distribution of price using matplotlib (default)

# %%
plt.hist(diamonds["price"])
plt.title('Distribution of price')
plt.xlabel('Price')
plt.show()

# %%
# We can set the number of bins with the `bins` kwarg
plt.hist(diamonds["price"], bins=50)
plt.title('Distribution of price')
plt.xlabel('Price')
plt.show()

# %% [markdown]
# # You can create a function to define the theme parameters to be used throught the kernel

# %%
def display_graph(ax, title, xlabel, ylabel, legend):
    '''
    Graph theme will be same throught the kernel
    '''
    ax.set_xlabel(xlabel, fontsize=16)
    ax.set_ylabel(ylabel, fontsize=16)
    plt.title(title, fontsize=18, fontweight='bold')
    plt.legend(legend)
    plt.show()

ax = sns.distplot(diamonds[['price']])
display_graph(ax, '', 'Price', '', ['price'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # Boxplot of price by clarity

# %%
plt.figure(figsize=(13,10), dpi= 80)
sns.boxplot(x='clarity', y='price', data=diamonds, notch=False)

# %% [markdown]
# # Categorical Plot

# %%
g = sns.catplot("cut", col="clarity", col_wrap=4,
                data=diamonds,
                kind="count", height=3.5, aspect=.8, 
                palette='tab20')

fig.suptitle('sf')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
f, axes = plt.subplots(1, 3, figsize=(20, 7), sharex=False,sharey=True)
sns.barplot(x="clarity",y="price", data=diamonds,ax=axes[ 0])

g=sns.barplot(x="cut",y="price", data=diamonds,ax=axes[ 1])
axes[1].set_title('Average price by category',y=1.08,fontdict={'fontsize': 40,'fontweight':20,'color':'black','fontfamily':'Monotype Corsiva'})

sns.barplot(x="color",y="price", data=diamonds,ax=axes[ 2])

# %%
# Create a visualization
sns.relplot(
    data=diamonds,
    x="carat", y="price", col="cut",
    hue="color", style="color", size="depth",
)

# %%
sns.lmplot(y="price", x="carat", hue="clarity", data= diamonds, fit_reg= False)

# %%
sns.lmplot(y="price", x="carat", hue="clarity", data= diamonds[diamonds.clarity == "SI2"], fit_reg= False)

# %%
plt.scatter(diamonds[diamonds.clarity == "SI2"]['carat'], diamonds[diamonds.clarity == "SI2"]['price'], alpha = 0.1)
plt.xlabel('Carat')
plt.ylabel('Price')
plt.title('Carat vs price')
# Out:
# Text(0.5, 1.0, 'Carat vs price')

# %%
plt.scatter(diamonds['carat'], diamonds['price'], alpha = 0.1)
plt.xlabel('Carat')
plt.ylabel('Price')
plt.title('Carat vs price')

# %% [markdown]
# # Pairplot is a way to see the correlation between numerical variables

# %%
sns.pairplot(diamonds)

# %% [markdown]
# ## You can identify categories by colours

# %%
sns.pairplot(data=diamonds,hue='cut')
plt.show()

# %% [markdown]
# # Scatter plot with linear regression line of best fit

# %%
# Plot
sns.set_style("white")
gridobj = sns.lmplot(x="carat", y="price", hue="cut", data=diamonds, 
                     height=7, aspect=1.6, robust=True, palette='tab10', 
                     scatter_kws=dict(s=60, linewidths=.7, edgecolors='black'))

# Decorations
gridobj.set(xlim=(0, 5), ylim=(0, 20000))
plt.title("Scatterplot with line of best fit grouped by cut", fontsize=20)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# Each regression line in its own column
# Each line in its own column
sns.set_style("white")
gridobj = sns.lmplot(x="carat", y="price", 
                     data=diamonds, 
                     height=7, 
                     robust=True, 
                     palette='Set1', 
                     col="cut",
                     scatter_kws=dict(s=60, linewidths=.7, edgecolors='black'))

# Decorations
gridobj.set(xlim=(0, 5), ylim=(0, 20000))
plt.show()

# %%
# Set the palette using the name of a palette:
sns.set_palette("Paired")
 
# Plot a chart:
sns.stripplot(x="clarity", y="price", data=diamonds)

# %%
# Plot
plt.figure(figsize=(12,10), dpi= 80)
sns.heatmap(diamonds.corr(), xticklabels=diamonds.corr().columns, yticklabels=diamonds.corr().columns, cmap='RdYlGn', center=0, annot=True)

# Decorations
plt.title('Correlogram', fontsize=22)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %% [markdown]
# # References
#
# * https://seaborn.pydata.org/
# * https://seaborn.pydata.org/examples/index.html
# * https://matplotlib.org/
# * https://matplotlib.org/stable/gallery/index.html
# * https://analyticsindiamag.com/comparing-python-data-visualization-tools-matplotlib-vs-seaborn/#:~:text=Matplotlib%3A%20Matplotlib%20is%20mainly%20deployed,has%20easily%20interesting%20default%20themes.
#
# * https://www.codecademy.com/articles/seaborn-design-ii
# * https://www.machinelearningplus.com/plots/top-50-matplotlib-visualizations-the-master-plots-python/

# %% [markdown]
# ## <font color='red'> Happy Spring!</font>

# %%
from IPython.display import Image
Image(url='https://media.giphy.com/media/8QbwUh40Hl96yMgvOx/giphy.gif')
# Out:
# <img src="https://media.giphy.com/media/8QbwUh40Hl96yMgvOx/giphy.gif"/>
